# %%
import pandas as pd

df = pd.read_csv('2024-1.csv')

# %%
df[df.domain_name=='tiktok.com'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 129656 entries, 0 to 129655
# Data columns (total 18 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   machine_id         129656 non-null  int64
#  1   site_session_id    129656 non-null  int64
#  2   user_session_id    129656 non-null  int64
#  3   domain_id          129656 non-null  int64
#  4   pages_viewed       129656 non-null  int64
#  5   duration           129656 non-null  int64
#  6   event_date         129656 non-null  object
#  7   event_time         129656 non-null  object
#  8   tran_flg           0 non-null       float64
#  9   prod_category_id   0 non-null       float64
#  10  prod_name          0 non-null       object
#  11  basket_tot         0 non-null       float64
#  12  census_region      129656 non-null  int64
#  13  household_size     129656 non-null  int64
#  14  household_income   129656 non-null  int64
# ...

# %%
df[df.domain_name=='amazon.com'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50722 entries, 10763 to 61484
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   machine_id         50722 non-null  int64
#  1   site_session_id    50722 non-null  int64
#  2   user_session_id    50722 non-null  int64
#  3   domain_id          50722 non-null  int64
#  4   pages_viewed       50722 non-null  int64
#  5   duration           50722 non-null  int64
#  6   event_date         50722 non-null  object
#  7   event_time         50722 non-null  object
#  8   tran_flg           168 non-null    float64
#  9   prod_category_id   164 non-null    float64
#  10  prod_name          164 non-null    object
#  11  prod_qty           164 non-null    float64
#  12  prod_totprice      164 non-null    float64
#  13  basket_tot         164 non-null    float64
#  14  census_region      50722 non-null  int64
#  15  household_size     50722 non-null  int64
# ...

# %%
amazon = df[df.domain_name=='amazon.com']
tiktok = df[df.domain_name=='tiktok.com']

# %%
amazon.groupby('machine_id').size().describe()
# Out:
# count    29373.000000
# mean        20.319783
# std         57.950464
# min          1.000000
# 25%          2.000000
# 50%          5.000000
# 75%         15.000000
# max       1822.000000
# dtype: float64

# %%
amazon.groupby('machine_id').size().hist(bins=40)
# Out:
# <Axes: >

# %%
amazon.to_csv('amazon_short.csv', index=False)
